# %%
import pandas as pd
import numpy as np
import os

# %%
# %matplotlib inline
import matplotlib.pyplot as plt
import seaborn as sns

# %% [markdown]
# # Loading and Joining

# %%
pd.set_option('display.max_columns', None)

# %%
movies = pd.read_csv('Join_TMDB_Filtered.csv')

# %%
movies.columns
# Out:
# Index(['movieId', 'title', 'genres', 'release_year', 'Adventure', 'Animation',
#        'Children', 'Comedy', 'Fantasy', 'Romance', 'Drama', 'Action', 'Crime',
#        'Thriller', 'Horror', 'Mystery', 'Sci-Fi', 'IMAX', 'Documentary', 'War',
#        'Musical', 'Western', 'Film-Noir', '(no genres listed)',
#        'movielens_number_reviews', 'movielens_avg_rating', 'imdbId', 'tmdbId',
#        'tmdb_info', 'tmdb_cast'],
#       dtype='object')

# %%
tmovies = pd.read_csv('tmovies.csv')

# %%
movies = pd.merge(movies, tmovies, how='left', left_on='tmdbId', right_on='id',  suffixes=('', '_t'))

# %% [markdown]
# # Datetime

# %%
movies['release_date'] = pd.to_datetime(movies['release_date'])
movies['year'] = movies.release_date.dt.year
movies['month'] = movies.release_date.dt.month
movies['dow'] = movies.release_date.dt.weekday
movies['qtr'] = movies.release_date.dt.quarter

# %%
movies['qtr'] = movies['qtr'].astype('str')

# %% [markdown]
# # Revenue, Budget, Profit and Loss

# %%
movies['revenue'] = movies['revenue'] / 1000000
movies['budget'] = movies['budget'] / 1000000

# %%
movies['pl'] = movies['revenue'] - movies['budget']

# %% [markdown]
# NAs removed from budget and revenue

# %%
movies = movies[movies['budget'].notna()]

# %%
movies = movies[movies['revenue'].notna()]

# %%
movies[movies['revenue'] == 0]
# Out:
#       movieId                                              title  \
# 331     65927                                 Night Train (2009)
# 344     66240              Dead Like Me: Life After Death (2009)
# 346     66297        Futurama: Into the Wild Green Yonder (2009)
# 349     66335                  Afro Samurai: Resurrection (2009)
# 351     66385                               Taking Chance (2009)
# 353     66472                             Way of War, The (2009)
# 354     66503                      Rally On! (Ralliraita) (2009)
# 357     66517                            Against the Dark (2009)
# 359     66551                                   Red Sands (2009)
# 360     66579                                   Lost, The (2009)
# 361     66581                            Still Waiting... (2009)
# 363     66596                                Mystery Team (2009)
# 367     66691         Thick as Thieves (a.k.a. Code, The) (2009)
# ...

# %% [markdown]
# Distributions for both revenue and budget appear heavily right skewed, with most movies costing and making no money at all

# %%
sns.set(style="white", palette="muted", color_codes=True)
sns.set_context("notebook", font_scale=1.5)

# %%
movies = movies[movies['budget'].notna()]

# %%
f, ax = plt.subplots(figsize=(6, 5))
sns.distplot(movies['revenue'], kde=False).set_title('Revenue (USD m)')
plt.xlabel('')
plt.ylabel('freq')
sns.despine()

# %% [markdown]
# Check movies with zeros in budgets or revenue
#
# Looking at movies such as Afro Samura and Futurama on Wikipedia, we see that they have budgets, so these 0s should be missing values

# %%
movies[movies['budget'] == 0].head()
# Out:
#      movieId                                  title  \
# 199    62265         Accidental Husband, The (2009)
# 325    65810                       Notorious (2009)
# 330    65882                  Uninvited, The (2009)
# 331    65927                     Night Train (2009)
# 344    66240  Dead Like Me: Life After Death (2009)
#
#                                          genres  release_year  Adventure  \
# 199                       ['Comedy', 'Romance']          2009          0
# 325                        ['Drama', 'Musical']          2009          0
# 330  ['Drama', 'Horror', 'Mystery', 'Thriller']          2009          0
# 331           ['Action', 'Mystery', 'Thriller']          2009          0
# 344                       ['Comedy', 'Fantasy']          2009          0
#
#      Animation  Children  Comedy  Fantasy  Romance  Drama  Action  Crime  \
# 199          0         0       1        0        1      0       0      0
# ...

# %% [markdown]
# We will create a dataframe with only movies with budget and revenue greater than zero in order to prevent drawing inaccurate conclusions when analysing these variables

# %%
movies_1 = movies[(movies['revenue'] > 0) & (movies['budget'] > 0)]

# %% [markdown]
# The number of movies in the dataset has been greatly reduced, and while there are still many low values, the dataset looks a bit more believable

# %%
f, ax = plt.subplots(figsize=(6, 5))
sns.distplot(movies_1['revenue'], kde=False).set_title('Revenue (USD m)')
plt.xlabel('')
plt.ylabel('freq')
sns.despine()

# %%
f, ax = plt.subplots(figsize=(6, 5))
sns.distplot(movies_1['budget'], kde=False).set_title('Budget (USD m)')
plt.xlabel('')
plt.ylabel('freq')
sns.despine()

# %%
f, ax = plt.subplots(figsize=(6, 5))
sns.distplot(movies_1['pl'], kde=False).set_title('Profit (USD m)')
plt.xlabel('')
plt.ylabel('freq')
sns.despine()

# %% [markdown]
# Profit appears to be extremely closely related to revenue, which is expected.
#
# In fact, correlations between the 2 are so high that we will concentrate on revenue when conducting pair analysis

# %%
movies_1['revenue'].corr( movies_1['pl'])
# Out:
# 0.9827642317092786

# %%
f, ax = plt.subplots(figsize=(6, 5))
sns.regplot(movies_1['revenue'], movies_1['pl'])

plt.title('Profit vs Revenue')
plt.ylabel('Profit (USD m)')
plt.xlabel('Revenue (USD m)')
sns.despine()

# %% [markdown]
# In general, total revenues appear to be far higher than budgets

# %%
ax = movies_1.groupby('release_year')['revenue', 'budget', 'pl'].sum()\
    .sort_index(ascending=True)\
    .plot(kind='bar', color=['palegreen', 'pink', 'lightblue'], figsize=(6, 5))
plt.title('Total revenue, budget, and profit by year (USD)')
plt.xlabel('Release year')
plt.ylabel('USD(m)')
sns.despine()

# %% [markdown]
# The average movie appears to make more than its budget

# %%
ax = movies_1.groupby('release_year')['revenue', 'budget', 'pl'].agg(np.mean).sort_index(ascending=True)\
    .plot(kind='bar', color=['palegreen', 'pink', 'lightblue'], figsize=(6, 5))
plt.title('Mean revenue, budget, and profit by year (USD)')
plt.xlabel('Release year')
plt.ylabel('USD(m)')
sns.despine()

# %% [markdown]
# However, this hides the issue that the mean is heavily affected by outliers.

# %%
ax = movies_1.groupby('release_year')['revenue', 'budget', 'pl'].agg(np.median).sort_index(ascending=True)\
    .plot(kind='bar', color=['palegreen', 'pink', 'lightblue'], figsize=(6, 5))
plt.title('Median revenue, budget, and profit by year (USD)')
plt.xlabel('Release year')
plt.ylabel('USD(m)')
sns.despine()

# %% [markdown]
# In general, we see that revenues, budgets and profits are higher for quarters 2 and 3, Summer and Winter, the traditional holiday and blockbuster periods.

# %% [markdown]
# movies_1.groupby('qtr')['revenue', 'budget', 'pl'].sum().sort_index(ascending=True)\
#     .plot(kind='bar', color=['palegreen', 'pink', 'lightblue'], figsize=(6, 5))
# plt.title('Total revenue, budget, and profit\nby quarter (USD)')
# plt.xlabel('Quarter')
# plt.ylabel('USD(m)')
# sns.despine()

# %% [markdown]
# # Genre

# %%
movie_genres = pd.melt(pd.concat([movies['movieId'], movies.loc[:,'Adventure':'(no genres listed)']],axis=1), id_vars = ["movieId"],
                       var_name = "genre", value_name = "genre_n")
movie_genres.dropna(axis = 0, subset = ['genre'], inplace = True)

movie_genres.head()
# Out:
#    movieId      genre  genre_n
# 0    60684  Adventure        0
# 1    62265  Adventure        0
# 2    63072  Adventure        1
# 3    65585  Adventure        0
# 4    65601  Adventure        0

# %%
movie_genres = movie_genres[movie_genres['genre_n'] != 0]

# %% [markdown]
# Dramas appear to have been the most common genre of movie, followed by comedies, thrillers and documentaries

# %%
movie_genres['genre'].value_counts().sort_values(ascending=True).plot(kind='barh', color='lightblue',figsize=(10, 8))
plt.title('Genre')
plt.xlabel('freq')
sns.despine()

# %%
mg = pd.merge(movie_genres, movies[['movieId', 'title', 'movielens_avg_rating']], how='left', left_on='movieId', right_on='movieId')

# %%
f, ax = plt.subplots(figsize=(10, 8))

res = mg.groupby(["genre"])['movielens_avg_rating'].aggregate(np.mean).reset_index().sort_values('movielens_avg_rating')
sns.barplot(y='genre', x="movielens_avg_rating", data=mg, order=res['genre'], color='lightblue')

#sns.barplot(y='genre', x='movielens_avg_rating', data=mg, estimator=np.median, color='lightblue')
plt.title('Avg Rating by Genre')
plt.xlabel('Avg Rating')
plt.ylabel('Genre')
# Out:
# Text(0,0.5,'Genre')

# %% [markdown]
# # Revenue vs Genre

# %% [markdown]
# We will examine revenue as proxy for popularity

# %%
movie_genres_1 = pd.melt(pd.concat([movies_1['movieId'], movies_1.loc[:,'Adventure':'(no genres listed)']],axis=1), id_vars = ["movieId"],
                       var_name = "genre", value_name = "genre_n")

movie_genres_1.dropna(axis = 0, subset = ['genre'], inplace = True)
movie_genres_1 = movie_genres_1[movie_genres_1['genre_n'] != 0]

mg_1 = pd.merge(movie_genres_1, movies_1[['movieId', 'revenue', 'budget', 'pl']], how='left', left_on='movieId', right_on='movieId')

# %%
mg_1.head()
# Out:
#    movieId      genre  genre_n     revenue  budget          pl
# 0    63072  Adventure        1   27.635305    32.0   -4.364695
# 1    66304  Adventure        1   73.034460    35.0   38.034460
# 2    66639  Adventure        1   12.764201    50.0  -37.235799
# 3    68358  Adventure        1  385.680446   150.0  235.680446
# 4    68791  Adventure        1  371.353001   200.0  171.353001

# %% [markdown]
# We will use median, given that the very high skew will adversely affect mean
# We see that strangely the median IMAX movie has the greatest median revenue, followed by animation and adventure.
# IMAX may have a higher median bacause only studios that are confident of a good reception might release in IMAX, while the others might be more suitable for family trips to the movies.

# %%
f, ax = plt.subplots(figsize=(10, 8))

res1 = mg_1.groupby(["genre"])['revenue'].aggregate(np.median).reset_index().sort_values('revenue', ascending=False)
sns.barplot(y='genre', x='revenue', data=mg_1, estimator=np.median, order=res1['genre'], color='lightblue')
plt.title('Median Revenue by Genre')
plt.xlabel('Median Revenue (USD m)')
plt.ylabel('Genre')
# Out:
# Text(0,0.5,'Genre')

# %% [markdown]
# # Revenue vs Budget

# %% [markdown]
# We plot revenue against budget to further explore their relationship and see an immediate positive relationshipm confirmed by an upward sloping regression line. A strong correlation of 0.78 reinforces this relationship.

# %%
f, ax = plt.subplots(figsize=(10, 8))

sns.regplot(movies_1['budget'], movies_1['revenue'])

plt.title('Revenue vs Budget')
plt.ylabel('Revenue (USD m)')
plt.xlabel('Budget (USD m)')
sns.despine()

# %%
movies_1['budget'].corr( movies_1['revenue'])
# Out:
# 0.7759705906525366

# %% [markdown]
# Budget of the movie appears to be strongly positively related to the popularity of the movie, and should be a strong predictor of it.

# %% [markdown]
# # Recommendation

# %% [markdown]
# Assuming that a person was to choose Fantasy

# %%
result = movies_1[movies_1['genres'].str.contains('Fantasy')][['title', 'revenue', 'budget', 'popularity', 'movielens_avg_rating']]

# %% [markdown]
# Fantasy movies with the highest ratings contain some rather obscure titles that might not be the best choice to recommend

# %%
sns.set_context("notebook", font_scale=1)
f, ax = plt.subplots(figsize=(8, 4))
sns.barplot(y='title', x='movielens_avg_rating', data=result.sort_values('movielens_avg_rating', ascending=False).head(10), color='lightblue')
plt.title('Fantasy movies with the highest ratings')
sns.despine()

# %% [markdown]
# On the other hand, movies with the highest revenues might not be that enjoyable

# %%
sns.set_context("notebook", font_scale=1)
f, ax = plt.subplots(figsize=(8, 4))
sns.barplot(y='title', x='revenue', data=result.sort_values('revenue', ascending=False).head(10), color='lightblue')
plt.title('Fantasy movies with the highest revenues')
sns.despine()

# %% [markdown]
# Instead, by taking a intersection of the highest rated movies and the highest ratings, we should be able to produce good recommendations with both mass-market appeal and enjoyablity

# %%
result[(result['revenue'].rank(ascending=False) < 20) & (result['movielens_avg_rating'].rank(ascending=False) < 20)]\
    [['title', 'revenue','movielens_avg_rating']].sort_values('movielens_avg_rating', ascending=False)
# Out:
#                                                   title      revenue  \
# 1102                                 Toy Story 3 (2010)  1066.969703
# 1940  Harry Potter and the Deathly Hallows: Part 2 (...  1342.000000
# 1428  Harry Potter and the Deathly Hallows: Part 1 (...   954.305868
# 1430                                     Tangled (2010)   591.794936
# 524       Harry Potter and the Half-Blood Prince (2009)   933.959197
# 3181          Hobbit: An Unexpected Journey, The (2012)  1021.103568
# 4341        Hobbit: The Desolation of Smaug, The (2013)   958.400000
# 4365                                      Frozen (2013)  1274.219009
#
#       movielens_avg_rating
# 1102              4.012974
# 1940              3.950665
# 1428              3.879119
# 1430              3.841263
# 524               3.815312
# 3181              3.793884
# 4341              3.731915
# 4365              3.706186
